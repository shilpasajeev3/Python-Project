# %% [markdown]
# Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns.

# %% [markdown]
# #### Import necessary modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Read dataset

# %%
df=pd.read_csv('myexcel.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# #### Pre processing of dataset

# %%
# Change data in column height with random numbers between 150 and 180
height_data=np.random.randint(150,181,size=len(df))
df['Height']=height_data
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     159     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     161     235
# 2     John Holland  Boston Celtics      30       SG   27     174     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     178     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     156     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     168     203
# 454      Raul Neto       Utah Jazz      25       PG   24     171     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     154     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     155     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     159     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     161     235
# 2   John Holland  Boston Celtics      30       SG   27     174     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     178     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     156     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     168     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     171     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     154     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     170     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     155     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %%
df.describe(include='all')
# Out:
#                   Name                  Team      Number Position         Age  \
# count              458                   458  458.000000      458  458.000000
# unique             458                    30         NaN        5         NaN
# top     Lucas Nogueira  New Orleans Pelicans         NaN       SG         NaN
# freq                 1                    19         NaN      102         NaN
# mean               NaN                   NaN   17.713974      NaN   26.934498
# std                NaN                   NaN   15.966837      NaN    4.400128
# min                NaN                   NaN    0.000000      NaN   19.000000
# 25%                NaN                   NaN    5.000000      NaN   24.000000
# 50%                NaN                   NaN   13.000000      NaN   26.000000
# 75%                NaN                   NaN   25.000000      NaN   30.000000
# max                NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %%
df.isnull().sum() # To check if there are any missing values
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
df.duplicated().sum() # To count number of duplicate rows
# Out:
# 0

# %%
df.columns # View column names
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# #### 1.How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
team_count=df['Team'].value_counts()
total_count=len(df)
percentage=(team_count/total_count)*100
result=pd.DataFrame({"Number of employees":team_count,'Percentage splitting':percentage})
print(result)
# Out:
#                         Number of employees  Percentage splitting
# New Orleans Pelicans                     19              4.148472
# Memphis Grizzlies                        18              3.930131
# Utah Jazz                                16              3.493450
# Milwaukee Bucks                          16              3.493450
# New York Knicks                          16              3.493450
# Oklahoma City Thunder                    15              3.275109
# Golden State Warriors                    15              3.275109
# Washington Wizards                       15              3.275109
# Denver Nuggets                           15              3.275109
# Los Angeles Lakers                       15              3.275109
# San Antonio Spurs                        15              3.275109
# Houston Rockets                          15              3.275109
# Boston Celtics                           15              3.275109
# ...

# %% [markdown]
# #### 2.Segregate the employees w.r.t different positions.

# %%
df['Position'].value_counts()
# Out:
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: Position, dtype: int64

# %% [markdown]
# #### 3.Find from which age group most of the employees belong to.

# %%
age_count=df['Age'].value_counts()
print("Age group most employees belong to:",age_count.idxmax())
print("Number of employees:",age_count.max())
# Out:
# Age group most employees belong to: 24
# Number of employees: 47

# %% [markdown]
# #### 4.Find out under which team and position, spending in terms of salary is high.

# %%
highest_salary=df['Salary'].idxmax()
hs=df.loc[highest_salary,['Team','Position']]
print("Highest Salary:",df['Salary'].max())
print(hs)
# Out:
# Highest Salary: 25000000.0
# Team        Los Angeles Lakers
# Position                    SF
# Name: 109, dtype: object

# %% [markdown]
# #### 5.Find if there is any correlation between age and salary , represent it visually.

# %%
corr=df[['Age','Salary']].corr()
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between age and salary')
sns.heatmap(corr,annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# From the information above, the correlation between age and salary indicates a weak positive correlation as the value is close to 0. As age increases salary also tends to increase but that wont be true in all case.

# %%
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between age and salary')
sns.scatterplot(x='Age',y='Salary', data=df)
plt.show()

# %% [markdown]
# As you can see from the above scatter plot, the plotting of points indicate that salary does not always increase with age.
